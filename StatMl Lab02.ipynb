# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal
# %matplotlib inline

# %%
covariance = np.array([[0.14, -0.3, 0.0, 0.2],
                       [-0.3, 1.16, 0.2, -0.8],
                       [0.0, 0.2, 1.0, 1.0],
                       [0.2, -0.8, 1.0, 2.0]])
precision = np.linalg.inv(covariance)
print(precision)
# Out:
# [[ 60.   50.  -48.   38. ]
#  [ 50.   50.  -50.   40. ]
#  [-48.  -50.   52.4 -41.4]
#  [ 38.   40.  -41.4  33.4]]

# %%
def generate_pair():
    return np.random.multivariate_normal([0.8, 0.8], [[0.1, -0.1],[-0.1, 0.12]])

# %%
mu_t = generate_pair()
print(mu_t)
# Out:
# [0.71166222 0.77264162]

# %%
x, y = np.mgrid[-0.25:2.25:.01, -1:2:.01]
pos = np.empty(x.shape + (2,))
pos[:, :, 0] = x
pos[:, :, 1] = y
mu_p = [0.8, 0.8]
cov_p = [[0.1, -0.1], [-0.1, 0.12]]
z = multivariate_normal(mu_p, cov_p).pdf(pos)

fig = plt.figure(figsize=(10, 10), dpi=500)
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x, y, z, cmap=plt.cm.viridis)
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
ax.set_zlabel('$p(x_1, x_2 | x_3=0, x_4=0)$')
plt.savefig('cond_mvg.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
N = 1000

# %%
import numpy as np
data = np.random.multivariate_normal([0.28, 1.18], [[2.0, 0.8], [0.8, 4.0]], N)
data
np.savetxt('data.txt',data)

# %%
import pandas as pd
data = pd.read_table('data.txt')
data = np.loadtxt('data.txt')
data
# Out:
# array([[-0.64916833,  1.76592056],
#        [-0.76658551,  0.66037787],
#        [ 0.64456628,  0.22097764],
#        ...,
#        [ 1.88064677,  2.18550732],
#        [ 0.96817203,  1.41106946],
#        [ 0.37715731,  1.03201353]])

# %%
mu_ml = data.mean(axis=0)
x = data - mu_ml
cov_ml = np.dot(x.T, x) / N #given equation for ML
cov_ml_unbiased = np.dot(x.T, x) / (N - 1)
print(mu_ml)
print(cov_ml)
print(cov_ml_unbiased)
# Out:
# [0.25095488 1.28782418]
# [[2.10210253 0.71726949]
#  [0.71726949 4.00048736]]
# [[2.10420673 0.71798747]
#  [0.71798747 4.00449185]]

# %%
def seq_ml(data):
    mus = [np.array([[0], [0]])]
    for i in range(N):
        x_n = data[i].reshape(2, 1)
        mu_n = mus[-1] + (x_n-mus[-1]) / (i + 1)
        mus.append(mu_n)
    return mus

# %%
mus_ml = seq_ml(data)
print(mus_ml[-1])
# Out:
# [[0.25095488]
#  [1.28782418]]

# %%
mu_p = np.array([[0.28], [1.18]])
cov_p = np.array([[0.1, -0.1], [-0.1, 0.12]])
cov_t = np.array([[2.0, 0.8], [0.8, 4.0]])
print(mu_p)
# Out:
# [[0.28]
#  [1.18]]

# %%
def seq_map(data, mu_p, cov_p, cov_t):
    mus, covs = [mu_p], [cov_p]
    for x in data:
        x_n = x.reshape(2, 1)
        cov_n = np.linalg.inv(np.linalg.inv(covs[-1]) + np.linalg.inv(cov_t))
        mu_n = cov_n.dot(np.linalg.inv(cov_t).dot(x_n) + np.linalg.inv(covs[-1]).dot(mus[-1]))
        mus.append(mu_n)
        covs.append(cov_n)

    return mus, covs

# %%
mus_map, covs_map = seq_map(data, mu_p, cov_p, cov_t)
print(mus_map[-1])
# Out:
# [[0.24358762]
#  [1.27423746]]

# %%
X = np.arange(N+1)
mus1_ml = [mu[0] for mu in mus_ml]
mus2_ml = [mu[1] for mu in mus_ml]
mus1_map = [mu[0] for mu in mus_map]
mus2_map = [mu[1] for mu in mus_map]
mus1_t = [0.28] * (N+1)
mus2_t = [1.18] * (N+1)
plt.style.use('ggplot')
plt.plot(X, mus1_ml, label='ML $\mu_1$')
plt.plot(X, mus2_ml, label='ML $\mu_2$')
plt.plot(X, mus1_map, label='MAP $\mu_1$')
plt.plot(X, mus2_map, label='MAP $\mu_2$')
plt.plot(X, mus1_t, label='True $\mu_1$')
plt.plot(X, mus2_t, label='True $\mu_2$')
plt.xlabel('$n$-th data point')
plt.ylabel('$\mu$')
plt.legend(loc=4)
plt.savefig('seq_learning.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
def p_xk(x, alpha, beta):
    return beta / (np.pi * (beta**2 + (x-alpha)**2))  #b/pi=(b+b +(x+A) (x-A)) probility

# %%
x = np.linspace(-4, 8, num=1000)
probs = p_xk(x, 2, 1)
plt.plot(x, probs)
plt.xlabel('$x_k$')
plt.ylabel(r'$p(x_k | \alpha, \beta)$')
plt.savefig('prob_xk.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
def p_a(x, alpha, beta):
    return np.product(beta / (np.pi * beta**2 + (x-alpha)**2))

# %%
D = np.array([4.8, -2.7, 2.2, 1.1, 0.8, -7.3])
alphas = np.linspace(-5, 5, num=1000)
beta = 1
likelihoods = [p_a(D, alpha, beta) for alpha in alphas]
plt.plot(alphas, likelihoods)
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$p(a | D, \beta)$')
plt.savefig('prob_a.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
print(D.mean())
print(alphas[np.argmax(likelihoods)])
# Out:
# -0.18333333333333326
# 1.1761761761761758

# %%
alpha_t = np.random.uniform(0, 10)
beta_t = np.random.uniform(1, 2)
print(alpha_t, beta_t)
# Out:
# 2.486124475047784 1.6610277028571643

# %%
def location(angle, alpha, beta):
    return beta * np.tan(angle) + alpha

# %%
N = 200
angles = np.random.uniform(-np.pi/2, np.pi/2, N)
locations = np.array([location(angle, alpha_t, beta_t) for angle in angles])

# %%
mus = [locations[:i + 1].mean() for i in range(N)]
mean = [locations.mean()] * (N)
X = np.arange(1, N + 1)
plt.style.use('ggplot')
plt.plot(X, mus, label='Mean over time')
plt.plot(X, mean, label='True mean')
plt.xlabel('$n$-th data point')
plt.ylabel(r'$\alpha$ (km)')
plt.legend()
plt.savefig('mean_x.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
print(locations.mean())
# Out:
# 3.0056492913574306

# %%
plt.style.use('classic')
ks = [1, 2, 3, 20]
alphas, betas = np.mgrid[-10:10:0.04, 0:5:0.04]
# alphas, betas = np.meshgrid(np.linspace(-10, 10, num=500), np.linspace(0, 5, num=250))
for k in ks:
    x = locations[:k]
    # We only have to calculate the constant once
    likelihood = k * np.log(betas/np.pi)
    for loc in x:
        likelihood -= np.log(betas**2 + (loc - alphas)**2)

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.plot_surface(alphas, betas, likelihood, cmap=plt.cm.viridis, vmin=-200, vmax=likelihood.max())
    plt.xlabel(r'$\alpha$')
    plt.ylabel(r'$\beta$')
    ax.set_zlabel('$\ln p(D | \alpha, \beta)$')
    plt.title('Log likelihood for $k = {}$'.format(k))
    plt.savefig('logl_{}.png'.format(k), bbox_inches='tight', dpi=300)
    plt.show()
# Out:
# <ipython-input-45-f58e94a921d6>:8: RuntimeWarning: divide by zero encountered in log
#   likelihood = k * np.log(betas/np.pi)
# /usr/local/lib/python3.10/dist-packages/mpl_toolkits/mplot3d/proj3d.py:180: RuntimeWarning: invalid value encountered in true_divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w

# %%
from scipy.optimize import fmin

def log_likelihood(params, locations):
    alpha, beta = params
    likelihood = len(locations) * np.log(beta/np.pi)
    for loc in locations:
        likelihood -= np.log(beta**2 + (loc - alpha)**2)
    return -likelihood

def plot_maximize_logl(data, alpha_t, beta_t):
    alphas, betas = [], []
    x = np.arange(len(data))
    for k in x:
        [alpha, beta] = fmin(log_likelihood, (0, 1), args=(data[:k],))
        alphas.append(alpha)
        betas.append(beta)

    plt.style.use('ggplot')
    plt.plot(x, alphas, label=r'$\alpha$')
    plt.plot(x ,betas, label=r'$\beta$')
    plt.plot(x, [alpha_t]*len(data), label=r'$\alpha_t$')
    plt.plot(x, [beta_t]*len(data), label=r'$\beta_t$')
    plt.xlabel('$k$')
    plt.ylabel('location (km)')
    plt.legend()
    plt.savefig('plots/min_logl.png', bbox_inches='tight', dpi=300)
    plt.show()

    print(alphas[-1], betas[-1])

# %%
plot_maximize_logl(locations, alpha_t, beta_t)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 10
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: 3.254433
#          Iterations: 84
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 3.619533
#          Iterations: 69
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 12.709593
#          Iterations: 73
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 16.646141
#          Iterations: 68
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 18.734307
#          Iterations: 77
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 28.052835
#          Iterations: 70
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 29.867649
#          Iterations: 70
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 35.765864
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 37.565148
#          Iterations: 73
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 39.202490
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 41.071219
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 43.070955
#          Iterations: 72
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 45.709416
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 47.725121
#          Iterations: 62
#          Function evaluations: 121
# Optimization terminated successfully.
#          Current function value: 49.289933
#          Iterations: 65
#          Function evaluations: 123
# Optimization terminated successfully.
#          Current function value: 50.479326
#          Iterations: 72
#          Function evaluations: 134
# <ipython-input-46-d9c80f915a7b>:5: RuntimeWarning: invalid value encountered in log
#   likelihood = len(locations) * np.log(beta/np.pi)
# <ipython-input-46-d9c80f915a7b>:14: RuntimeWarning: Maximum number of function evaluations has been exceeded.
#   [alpha, beta] = fmin(log_likelihood, (0, 1), args=(data[:k],))
# Optimization terminated successfully.
#          Current function value: 52.452891
#          Iterations: 71
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 55.870292
#          Iterations: 66
#          Function evaluations: 123
# Optimization terminated successfully.
#          Current function value: 57.902104
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 63.847604
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 65.366611
#          Iterations: 64
#          Function evaluations: 121
# Optimization terminated successfully.
#          Current function value: 66.603945
#          Iterations: 65
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 67.836199
#          Iterations: 75
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 70.139377
#          Iterations: 68
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 74.920026
#          Iterations: 65
#          Function evaluations: 122
# Optimization terminated successfully.
#          Current function value: 76.114992
#          Iterations: 68
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 77.367155
#          Iterations: 68
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 80.384238
#          Iterations: 78
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 86.581269
#          Iterations: 69
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 91.355531
#          Iterations: 68
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 94.013283
#          Iterations: 79
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 95.876885
#          Iterations: 68
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 97.599455
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 98.967176
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 100.986914
#          Iterations: 66
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 106.496490
#          Iterations: 71
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 108.132843
#          Iterations: 70
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 109.431108
#          Iterations: 71
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 114.334244
#          Iterations: 77
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 116.013148
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 122.031817
#          Iterations: 77
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 123.912652
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 130.694203
#          Iterations: 68
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 132.076440
#          Iterations: 76
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 135.147089
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 141.824906
#          Iterations: 76
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 143.231620
#          Iterations: 76
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 144.853470
#          Iterations: 78
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 146.481633
#          Iterations: 68
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 149.410373
#          Iterations: 70
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 152.662503
#          Iterations: 66
#          Function evaluations: 124
# Optimization terminated successfully.
#          Current function value: 154.580657
#          Iterations: 69
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 163.993869
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 166.859767
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 168.326124
#          Iterations: 67
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 170.060052
#          Iterations: 70
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 172.454210
#          Iterations: 77
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 179.031009
#          Iterations: 67
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 180.477518
#          Iterations: 70
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 181.958560
#          Iterations: 71
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 186.053420
#          Iterations: 70
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 193.097553
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 198.552780
#          Iterations: 71
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 202.106243
#          Iterations: 72
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 204.596476
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 208.073688
#          Iterations: 70
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 209.938288
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 213.634131
#          Iterations: 68
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 215.184117
#          Iterations: 74
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 221.293686
#          Iterations: 74
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 222.958371
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 227.381942
#          Iterations: 68
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 228.902738
#          Iterations: 68
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 230.510545
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 232.662455
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 236.275897
#          Iterations: 70
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 237.753666
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 241.632184
#          Iterations: 69
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 243.260146
#          Iterations: 71
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 252.680649
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 254.790956
#          Iterations: 82
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 256.263518
#          Iterations: 67
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 259.535829
#          Iterations: 66
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 261.191506
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 262.974161
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 264.586506
#          Iterations: 69
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 265.996526
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 267.504710
#          Iterations: 65
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 270.164166
#          Iterations: 78
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 272.351537
#          Iterations: 70
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 278.614520
#          Iterations: 79
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 280.011970
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 281.535212
#          Iterations: 75
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 283.768157
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 285.136563
#          Iterations: 78
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 286.766264
#          Iterations: 68
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 288.151600
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 289.486445
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 291.595483
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 292.952332
#          Iterations: 76
#          Function evaluations: 143
# Optimization terminated successfully.
#          Current function value: 294.621361
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 297.841102
#          Iterations: 71
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 299.684543
#          Iterations: 76
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 304.252095
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 305.561741
#          Iterations: 70
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 309.130880
#          Iterations: 69
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 311.067947
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 312.361459
#          Iterations: 70
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 315.332331
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 318.359897
#          Iterations: 68
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 327.706926
#          Iterations: 70
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 331.862777
#          Iterations: 73
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 334.657298
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 336.665358
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 344.619645
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 347.566309
#          Iterations: 68
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 349.285244
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 351.130338
#          Iterations: 69
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 352.779020
#          Iterations: 73
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 354.289472
#          Iterations: 75
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 357.377355
#          Iterations: 66
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 364.714940
#          Iterations: 72
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 368.042670
#          Iterations: 72
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 369.468448
#          Iterations: 68
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 371.441715
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 377.746815
#          Iterations: 66
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 382.577264
#          Iterations: 84
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 387.145506
#          Iterations: 71
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 388.565208
#          Iterations: 74
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 390.678483
#          Iterations: 78
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 393.560588
#          Iterations: 68
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 395.055663
#          Iterations: 76
#          Function evaluations: 147
# Optimization terminated successfully.
#          Current function value: 399.533718
#          Iterations: 70
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 400.938457
#          Iterations: 73
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 403.590886
#          Iterations: 75
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 407.522523
#          Iterations: 70
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 409.655503
#          Iterations: 73
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 411.703601
#          Iterations: 83
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 413.243260
#          Iterations: 80
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 414.649610
#          Iterations: 75
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 417.809102
#          Iterations: 78
#          Function evaluations: 145
# Optimization terminated successfully.
#          Current function value: 419.911718
#          Iterations: 76
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 421.643111
#          Iterations: 68
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 423.687554
#          Iterations: 74
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 431.470540
#          Iterations: 75
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 433.248906
#          Iterations: 74
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 434.644846
#          Iterations: 68
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 436.931002
#          Iterations: 78
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 438.816941
#          Iterations: 73
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 440.211449
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 442.579811
#          Iterations: 67
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 448.865316
#          Iterations: 73
#          Function evaluations: 137
# Optimization terminated successfully.
#          Current function value: 454.074026
#          Iterations: 66
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 455.548885
#          Iterations: 65
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 457.075117
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 458.797788
#          Iterations: 68
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 464.602710
#          Iterations: 83
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 466.729399
#          Iterations: 70
#          Function evaluations: 135
# Optimization terminated successfully.
#          Current function value: 468.825329
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 470.207142
#          Iterations: 67
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 475.814290
#          Iterations: 70
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 482.150595
#          Iterations: 75
#          Function evaluations: 144
# Optimization terminated successfully.
#          Current function value: 486.697226
#          Iterations: 74
#          Function evaluations: 141
# Optimization terminated successfully.
#          Current function value: 488.358574
#          Iterations: 65
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 490.463250
#          Iterations: 65
#          Function evaluations: 126
# Optimization terminated successfully.
#          Current function value: 492.606063
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 494.376973
#          Iterations: 74
#          Function evaluations: 142
# Optimization terminated successfully.
#          Current function value: 496.577226
#          Iterations: 70
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 500.236485
#          Iterations: 73
#          Function evaluations: 139
# Optimization terminated successfully.
#          Current function value: 502.909045
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 506.773180
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 512.484488
#          Iterations: 65
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 514.491892
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 517.472264
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 519.147952
#          Iterations: 66
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 520.622216
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 522.058105
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 525.199678
#          Iterations: 67
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 531.706538
#          Iterations: 65
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 533.335449
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 536.091205
#          Iterations: 68
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 540.634068
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 543.135550
#          Iterations: 69
#          Function evaluations: 131
# Optimization terminated successfully.
#          Current function value: 544.666097
#          Iterations: 70
#          Function evaluations: 133
# Optimization terminated successfully.
#          Current function value: 546.346447
#          Iterations: 72
#          Function evaluations: 136
# Optimization terminated successfully.
#          Current function value: 552.160964
#          Iterations: 69
#          Function evaluations: 132
# Optimization terminated successfully.
#          Current function value: 554.386150
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 556.197928
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 560.254883
#          Iterations: 73
#          Function evaluations: 140
# Optimization terminated successfully.
#          Current function value: 562.037943
#          Iterations: 69
#          Function evaluations: 130
# Optimization terminated successfully.
#          Current function value: 564.083095
#          Iterations: 67
#          Function evaluations: 129
# Optimization terminated successfully.
#          Current function value: 565.594738
#          Iterations: 65
#          Function evaluations: 125
# Optimization terminated successfully.
#          Current function value: 568.493363
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 570.544860
#          Iterations: 71
#          Function evaluations: 134
# Optimization terminated successfully.
#          Current function value: 573.012379
#          Iterations: 67
#          Function evaluations: 127
# Optimization terminated successfully.
#          Current function value: 575.546650
#          Iterations: 73
#          Function evaluations: 138
# Optimization terminated successfully.
#          Current function value: 579.406802
#          Iterations: 66
#          Function evaluations: 128
# Optimization terminated successfully.
#          Current function value: 582.244417
#          Iterations: 70
#          Function evaluations: 132
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-9a8da75936ac> in <cell line: 1>()
# ----> 1 plot_maximize_logl(locations, alpha_t, beta_t)
#
# <ipython-input-46-d9c80f915a7b> in plot_maximize_logl(data, alpha_t, beta_t)
#      24     plt.ylabel('location (km)')
#      25     plt.legend()
# ---> 26     plt.savefig('plots/min_logl.png', bbox_inches='tight', dpi=300)
#      27     plt.show()
#      28
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/min_logl.png'

# %%
import pandas as pd
import numpy as np
a=pd.read_csv("train.csv",sep=';')
print(a)
p=a['hour']
m=np.mean(p)
sd=np.std(p)#sigma value
var=np.var(p)#sigma square value
m, sd, var
# Out:
#          id  year  hour  season  holiday  workingday  weather   temp   atemp  \
# 0         3  2012    23       3        0           0        2  23.78  27.275
# 1         4  2011     8       3        0           0        1  27.88  31.820
# 2         5  2012     2       1        0           1        1  20.50  24.240
# 3         7  2011    20       3        0           1        3  25.42  28.790
# 4         8  2011    17       3        0           1        3  26.24  28.790
# ...     ...   ...   ...     ...      ...         ...      ...    ...     ...
# 7684  10882  2012    18       1        0           1        1  13.94  15.150
# 7685  10883  2012     3       1        0           1        1   9.02  11.365
# 7686  10884  2012    15       2        0           0        1  21.32  25.000
# 7687  10885  2011    19       4        0           1        1  12.30  14.395
# 7688  10886  2012    21       3        0           1        1  30.34  34.850
#
#       humidity  windspeed  count
# 0           73    11.0014    133
# 1           57     0.0000    132
# 2           59     0.0000     19
# 3           83    19.9995     58
# 4           89     0.0000    285
# ...        ...        ...    ...
# 7684        42    22.0028    457
# 7685        51    11.0014      1
# 7686        19    27.9993    626
# 7687        45    15.0013    217
# 7688        66     7.0015    381
#
# [7689 rows x 12 columns]
# (11.56535310183379, 6.915326938018648, 47.82174665968637)

# %%
t=np.array(a['temp'])
tm=np.mean(t)
tsd=np.std(t)#sigma value/std.dev
tvar=np.var(t)#variance
x=29
l=np.log(np.sqrt(2*3.14))
e=np.log(tsd) #std.dev
f=(x-tm)**2 #mean
g=2*(tvar**2) #variance
h=f/g
i=-l-e
print(i-h)
# Out:
# -2.9860025235468406

# %%
import seaborn
import matplotlib.pyplot as plt
df = seaborn.load_dataset('tips')
seaborn.pairplot(df, hue='day')
plt.show()

# %%
import pandas as pd
import numpy as np
a=pd.read_csv("test.csv",sep=';')
print(a)
p=a['hour']
m=np.mean(p)
sd=np.std(p)#sigma value
var=np.var(p)#sigma square value
m, sd, var
import seaborn
import matplotlib.pyplot as plt
df = seaborn.load_dataset('tips')
seaborn.pairplot(df, hue='day')
plt.show()
# Out:
#          id  year  hour  season  holiday  workingday  weather   temp   atemp  \
# 0         3  2012    23       3        0           0        2  23.78  27.275
# 1         4  2011     8       3        0           0        1  27.88  31.820
# 2         5  2012     2       1        0           1        1  20.50  24.240
# 3         7  2011    20       3        0           1        3  25.42  28.790
# 4         8  2011    17       3        0           1        3  26.24  28.790
# ...     ...   ...   ...     ...      ...         ...      ...    ...     ...
# 7684  10882  2012    18       1        0           1        1  13.94  15.150
# 7685  10883  2012     3       1        0           1        1   9.02  11.365
# 7686  10884  2012    15       2        0           0        1  21.32  25.000
# 7687  10885  2011    19       4        0           1        1  12.30  14.395
# 7688  10886  2012    21       3        0           1        1  30.34  34.850
#
#       humidity  windspeed  count
# 0           73    11.0014    133
# 1           57     0.0000    132
# 2           59     0.0000     19
# 3           83    19.9995     58
# 4           89     0.0000    285
# ...        ...        ...    ...
# 7684        42    22.0028    457
# 7685        51    11.0014      1
# 7686        19    27.9993    626
# 7687        45    15.0013    217
# 7688        66     7.0015    381
#
# [7689 rows x 12 columns]
